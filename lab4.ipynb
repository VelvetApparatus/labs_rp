# %%
# %pip install TTS bark soundfile torch whisperspeech psutil
# %pip install torch
# %pip install whisperspeech
# %pip install psutil
# %pip install TTS bark soundfile
# %pip install speechbrain torchaudio
# Out:
# Requirement already satisfied: torch in /opt/homebrew/lib/python3.11/site-packages (2.6.0)
# Requirement already satisfied: filelock in /opt/homebrew/lib/python3.11/site-packages (from torch) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/homebrew/lib/python3.11/site-packages (from torch) (4.15.0)
# Requirement already satisfied: networkx in /opt/homebrew/lib/python3.11/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/homebrew/lib/python3.11/site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in /opt/homebrew/lib/python3.11/site-packages (from torch) (2024.5.0)
# Requirement already satisfied: sympy==1.13.1 in /opt/homebrew/lib/python3.11/site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/homebrew/lib/python3.11/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/lib/python3.11/site-packages (from jinja2->torch) (2.1.2)
#
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting whisperspeech
#   Obtaining dependency information for whisperspeech from https://files.pythonhosted.org/packages/86/d2/79287f07e8c5fce780b68ac0e01c195c8e4e5a8874d4d8c3a1dc65da71a2/WhisperSpeech-0.8.9-py3-none-any.whl.metadata
#   Downloading WhisperSpeech-0.8.9-py3-none-any.whl.metadata (11 kB)
# Collecting vocos (from whisperspeech)
#   Obtaining dependency information for vocos from https://files.pythonhosted.org/packages/0a/45/82fe9b5696eb5dd4f84632f75b549b48bed0c33a5920b6309fbafd7e3477/vocos-0.1.0-py3-none-any.whl.metadata
#   Downloading vocos-0.1.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting speechbrain<1.0 (from whisperspeech)
#   Obtaining dependency information for speechbrain<1.0 from https://files.pythonhosted.org/packages/30/ff/9629de25786cf6ce38b7754b352a9904ce8c90b22a127d9d0d9c45ef5693/speechbrain-0.5.16-py3-none-any.whl.metadata
#   Downloading speechbrain-0.5.16-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: requests in /opt/homebrew/lib/python3.11/site-packages (from whisperspeech) (2.32.3)
# Requirement already satisfied: huggingface-hub in /opt/homebrew/lib/python3.11/site-packages (from whisperspeech) (0.29.3)
# Collecting fastprogress (from whisperspeech)
#   Obtaining dependency information for fastprogress from https://files.pythonhosted.org/packages/a7/8f/213223fdee199c55db81e2d0c669f30e8285c5be2526c4ed924de39247da/fastprogress-1.0.3-py3-none-any.whl.metadata
#   Downloading fastprogress-1.0.3-py3-none-any.whl.metadata (5.6 kB)
# Collecting fastcore (from whisperspeech)
#   Obtaining dependency information for fastcore from https://files.pythonhosted.org/packages/27/f4/30077733807ca57cc504a6faadcdd067714a7891dad66231b0c1ab373551/fastcore-1.8.16-py3-none-any.whl.metadata
#   Downloading fastcore-1.8.16-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: torch>=2 in /opt/homebrew/lib/python3.11/site-packages (from whisperspeech) (2.6.0)
# Requirement already satisfied: torchaudio in /opt/homebrew/lib/python3.11/site-packages (from whisperspeech) (2.6.0)
# Requirement already satisfied: soundfile in /opt/homebrew/lib/python3.11/site-packages (from whisperspeech) (0.13.1)
# Collecting hyperpyyaml (from speechbrain<1.0->whisperspeech)
#   Obtaining dependency information for hyperpyyaml from https://files.pythonhosted.org/packages/33/c9/751b6401887f4b50f9307cc1e53d287b3dc77c375c126aeb6335aff73ccb/HyperPyYAML-1.2.2-py3-none-any.whl.metadata
#   Downloading HyperPyYAML-1.2.2-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: joblib in /opt/homebrew/lib/python3.11/site-packages (from speechbrain<1.0->whisperspeech) (1.4.2)
# Requirement already satisfied: numpy in /opt/homebrew/lib/python3.11/site-packages (from speechbrain<1.0->whisperspeech) (1.26.4)
# Requirement already satisfied: packaging in /opt/homebrew/lib/python3.11/site-packages (from speechbrain<1.0->whisperspeech) (25.0)
# Requirement already satisfied: scipy in /opt/homebrew/lib/python3.11/site-packages (from speechbrain<1.0->whisperspeech) (1.11.4)
# Requirement already satisfied: sentencepiece in /opt/homebrew/lib/python3.11/site-packages (from speechbrain<1.0->whisperspeech) (0.2.0)
# Requirement already satisfied: tqdm in /opt/homebrew/lib/python3.11/site-packages (from speechbrain<1.0->whisperspeech) (4.67.1)
# Requirement already satisfied: filelock in /opt/homebrew/lib/python3.11/site-packages (from torch>=2->whisperspeech) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/homebrew/lib/python3.11/site-packages (from torch>=2->whisperspeech) (4.15.0)
# Requirement already satisfied: networkx in /opt/homebrew/lib/python3.11/site-packages (from torch>=2->whisperspeech) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/homebrew/lib/python3.11/site-packages (from torch>=2->whisperspeech) (3.1.2)
# Requirement already satisfied: fsspec in /opt/homebrew/lib/python3.11/site-packages (from torch>=2->whisperspeech) (2024.5.0)
# Requirement already satisfied: sympy==1.13.1 in /opt/homebrew/lib/python3.11/site-packages (from torch>=2->whisperspeech) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/homebrew/lib/python3.11/site-packages (from sympy==1.13.1->torch>=2->whisperspeech) (1.3.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/homebrew/lib/python3.11/site-packages (from huggingface-hub->whisperspeech) (6.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/lib/python3.11/site-packages (from requests->whisperspeech) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/lib/python3.11/site-packages (from requests->whisperspeech) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/lib/python3.11/site-packages (from requests->whisperspeech) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/lib/python3.11/site-packages (from requests->whisperspeech) (2024.12.14)
# Requirement already satisfied: cffi>=1.0 in /opt/homebrew/lib/python3.11/site-packages (from soundfile->whisperspeech) (1.16.0)
# Collecting einops (from vocos->whisperspeech)
#   Obtaining dependency information for einops from https://files.pythonhosted.org/packages/87/62/9773de14fe6c45c23649e98b83231fffd7b9892b6cf863251dc2afa73643/einops-0.8.1-py3-none-any.whl.metadata
#   Downloading einops-0.8.1-py3-none-any.whl.metadata (13 kB)
# Collecting encodec==0.1.1 (from vocos->whisperspeech)
#   Downloading encodec-0.1.1.tar.gz (3.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 7.6 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pycparser in /opt/homebrew/lib/python3.11/site-packages (from cffi>=1.0->soundfile->whisperspeech) (2.22)
# Collecting ruamel.yaml>=0.17.28 (from hyperpyyaml->speechbrain<1.0->whisperspeech)
#   Obtaining dependency information for ruamel.yaml>=0.17.28 from https://files.pythonhosted.org/packages/0f/73/bb1bc2529f852e7bf64a2dec885e89ff9f5cc7bbf6c9340eed30ff2c69c5/ruamel.yaml-0.18.16-py3-none-any.whl.metadata
#   Downloading ruamel.yaml-0.18.16-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/lib/python3.11/site-packages (from jinja2->torch>=2->whisperspeech) (2.1.2)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml>=0.17.28->hyperpyyaml->speechbrain<1.0->whisperspeech)
#   Obtaining dependency information for ruamel.yaml.clib>=0.2.7 from https://files.pythonhosted.org/packages/53/09/de9d3f6b6701ced5f276d082ad0f980edf08ca67114523d1b9264cd5e2e0/ruamel_yaml_clib-0.2.15-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading ruamel_yaml_clib-0.2.15-cp311-cp311-macosx_11_0_arm64.whl.metadata (3.5 kB)
# Downloading WhisperSpeech-0.8.9-py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 4.6 MB/s eta 0:00:00
# Downloading speechbrain-0.5.16-py3-none-any.whl (630 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 630.6/630.6 kB 10.7 MB/s eta 0:00:00a 0:00:01
# Downloading fastcore-1.8.16-py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 892.5 kB/s eta 0:00:000:00:01
# Downloading fastprogress-1.0.3-py3-none-any.whl (12 kB)
# Downloading vocos-0.1.0-py3-none-any.whl (24 kB)
# Downloading einops-0.8.1-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.4/64.4 kB 4.3 MB/s eta 0:00:00
# Downloading HyperPyYAML-1.2.2-py3-none-any.whl (16 kB)
# Downloading ruamel.yaml-0.18.16-py3-none-any.whl (119 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.9/119.9 kB 1.2 MB/s eta 0:00:00 0:00:01
# Downloading ruamel_yaml_clib-0.2.15-cp311-cp311-macosx_11_0_arm64.whl (132 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.7/132.7 kB 7.0 MB/s eta 0:00:00
# Building wheels for collected packages: encodec
#   Building wheel for encodec (setup.py) ... done
#   Created wheel for encodec: filename=encodec-0.1.1-py3-none-any.whl size=45760 sha256=ffc72781a4a4c1c9648e01dbdbea6eabc060bebc1ec2b438f4ba8feb275d74f1
#   Stored in directory: /Users/velimirhlebnikov/Library/Caches/pip/wheels/b4/a4/88/480018a664e58ca7ce6708759193ee51b017b3b72aa3df8a85
# Successfully built encodec
# Installing collected packages: ruamel.yaml.clib, fastprogress, fastcore, einops, ruamel.yaml, hyperpyyaml, speechbrain, encodec, vocos, whisperspeech
# Successfully installed einops-0.8.1 encodec-0.1.1 fastcore-1.8.16 fastprogress-1.0.3 hyperpyyaml-1.2.2 ruamel.yaml-0.18.16 ruamel.yaml.clib-0.2.15 speechbrain-0.5.16 vocos-0.1.0 whisperspeech-0.8.9
#
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: psutil in /Users/velimirhlebnikov/Library/Python/3.11/lib/python/site-packages (5.9.8)
#
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting TTS
#   Downloading TTS-0.22.0.tar.gz (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 3.8 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting bark
#   Obtaining dependency information for bark from https://files.pythonhosted.org/packages/91/12/f5e8a31e0c0f25d8d1bc21edaeb0ac538f9bea917942ef5e2e31ee2cefa1/bark-0.1.5-py3-none-any.whl.metadata
#   Downloading bark-0.1.5-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: soundfile in /opt/homebrew/lib/python3.11/site-packages (0.13.1)
# Requirement already satisfied: cython>=0.29.30 in /opt/homebrew/lib/python3.11/site-packages (from TTS) (0.29.37)
# Requirement already satisfied: scipy>=1.11.2 in /opt/homebrew/lib/python3.11/site-packages (from TTS) (1.11.4)
# Requirement already satisfied: torch>=2.1 in /opt/homebrew/lib/python3.11/site-packages (from TTS) (2.6.0)
# Requirement already satisfied: torchaudio in /opt/homebrew/lib/python3.11/site-packages (from TTS) (2.6.0)
# Requirement already satisfied: librosa>=0.10.0 in /opt/homebrew/lib/python3.11/site-packages (from TTS) (0.11.0)
# Requirement already satisfied: scikit-learn>=1.3.0 in /opt/homebrew/lib/python3.11/site-packages (from TTS) (1.6.0)
# Collecting inflect>=5.6.0 (from TTS)
#   Obtaining dependency information for inflect>=5.6.0 from https://files.pythonhosted.org/packages/8a/eb/427ed2b20a38a4ee29f24dbe4ae2dafab198674fe9a85e3d6adf9e5f5f41/inflect-7.5.0-py3-none-any.whl.metadata
#   Downloading inflect-7.5.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: tqdm>=4.64.1 in /opt/homebrew/lib/python3.11/site-packages (from TTS) (4.67.1)
# Collecting anyascii>=0.3.0 (from TTS)
#   Obtaining dependency information for anyascii>=0.3.0 from https://files.pythonhosted.org/packages/c2/76/783b75a21ce3563b8709050de030ae253853b147bd52e141edc1025aa268/anyascii-0.3.3-py3-none-any.whl.metadata
#   Downloading anyascii-0.3.3-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: pyyaml>=6.0 in /opt/homebrew/lib/python3.11/site-packages (from TTS) (6.0.2)
# Requirement already satisfied: fsspec>=2023.6.0 in /opt/homebrew/lib/python3.11/site-packages (from TTS) (2024.5.0)
# Requirement already satisfied: aiohttp>=3.8.1 in /opt/homebrew/lib/python3.11/site-packages (from TTS) (3.9.5)
# Requirement already satisfied: packaging>=23.1 in /opt/homebrew/lib/python3.11/site-packages (from TTS) (25.0)
# Requirement already satisfied: flask>=2.0.1 in /opt/homebrew/lib/python3.11/site-packages (from TTS) (2.2.5)
# Collecting pysbd>=0.3.4 (from TTS)
#   Obtaining dependency information for pysbd>=0.3.4 from https://files.pythonhosted.org/packages/48/0a/c99fb7d7e176f8b176ef19704a32e6a9c6aafdf19ef75a187f701fc15801/pysbd-0.3.4-py3-none-any.whl.metadata
#   Using cached pysbd-0.3.4-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: umap-learn>=0.5.1 in /opt/homebrew/lib/python3.11/site-packages (from TTS) (0.5.6)
# Collecting pandas<2.0,>=1.4 (from TTS)
#   Obtaining dependency information for pandas<2.0,>=1.4 from https://files.pythonhosted.org/packages/b0/be/1843b9aff84b98899663e7cad9f45513dfdd11d69cb5bd85c648aaf6a8d4/pandas-1.5.3-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading pandas-1.5.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (11 kB)
# Requirement already satisfied: matplotlib>=3.7.0 in /opt/homebrew/lib/python3.11/site-packages (from TTS) (3.7.1)
# Collecting trainer>=0.0.32 (from TTS)
#   Obtaining dependency information for trainer>=0.0.32 from https://files.pythonhosted.org/packages/a0/38/c4381497fde987c72fc58d9b534dfd9e254e34d402e06be232f40e1baf66/trainer-0.0.36-py3-none-any.whl.metadata
#   Downloading trainer-0.0.36-py3-none-any.whl.metadata (8.1 kB)
# Collecting coqpit>=0.0.16 (from TTS)
#   Obtaining dependency information for coqpit>=0.0.16 from https://files.pythonhosted.org/packages/a3/d8/3f922be74a0aa9ef54ae1f82723fb1882988dce7fa420ba6af24e52c1987/coqpit-0.0.17-py3-none-any.whl.metadata
#   Using cached coqpit-0.0.17-py3-none-any.whl.metadata (11 kB)
# Collecting jieba (from TTS)
#   Using cached jieba-0.42.1-py3-none-any.whl
# Collecting pypinyin (from TTS)
#   Obtaining dependency information for pypinyin from https://files.pythonhosted.org/packages/b9/7b/4cabc76fcc21c3c7d5c671d8783984d30ac9d3bb387c4ba784fca3cdfa3a/pypinyin-0.55.0-py2.py3-none-any.whl.metadata
#   Downloading pypinyin-0.55.0-py2.py3-none-any.whl.metadata (12 kB)
# Collecting hangul-romanize (from TTS)
#   Obtaining dependency information for hangul-romanize from https://files.pythonhosted.org/packages/e9/12/c5d2efd69d634d33c1a0a90256116bdefd023b27ca477f1fc5c7620aa21f/hangul_romanize-0.1.0-py3-none-any.whl.metadata
#   Downloading hangul_romanize-0.1.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting gruut[de,es,fr]==2.2.3 (from TTS)
#   Using cached gruut-2.2.3-py3-none-any.whl
# Collecting jamo (from TTS)
#   Obtaining dependency information for jamo from https://files.pythonhosted.org/packages/ac/cc/49812faae67f9a24be6ddaf58a2cf7e8c3cbfcf5b762d9414f7103d2ea2c/jamo-0.4.1-py3-none-any.whl.metadata
#   Using cached jamo-0.4.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting nltk (from TTS)
#   Obtaining dependency information for nltk from https://files.pythonhosted.org/packages/60/90/81ac364ef94209c100e12579629dc92bf7a709a84af32f8c551b02c07e94/nltk-3.9.2-py3-none-any.whl.metadata
#   Downloading nltk-3.9.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting g2pkk>=0.1.1 (from TTS)
#   Obtaining dependency information for g2pkk>=0.1.1 from https://files.pythonhosted.org/packages/25/9e/37665b4cf4e99dd4d294b178f79cd70fed2c5beff995e77132ceda97cfa1/g2pkk-0.1.2-py3-none-any.whl.metadata
#   Using cached g2pkk-0.1.2-py3-none-any.whl.metadata (2.0 kB)
# Collecting bangla (from TTS)
#   Obtaining dependency information for bangla from https://files.pythonhosted.org/packages/e6/9f/73d69c27f2daf35c7d1ae0de6d8d97fa43f0507b1f25444111d313b7679b/bangla-0.0.5-py3-none-any.whl.metadata
#   Downloading bangla-0.0.5-py3-none-any.whl.metadata (4.7 kB)
# Collecting bnnumerizer (from TTS)
#   Downloading bnnumerizer-0.0.2.tar.gz (4.7 kB)
#   Preparing metadata (setup.py) ... done
# Collecting bnunicodenormalizer (from TTS)
#   Obtaining dependency information for bnunicodenormalizer from https://files.pythonhosted.org/packages/e9/37/df46a2375c462623ebf17258926cacb94e01a6159c93f9144a6b42bc33fe/bnunicodenormalizer-0.1.7-py3-none-any.whl.metadata
#   Downloading bnunicodenormalizer-0.1.7-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: einops>=0.6.0 in /opt/homebrew/lib/python3.11/site-packages (from TTS) (0.8.1)
# Requirement already satisfied: transformers>=4.33.0 in /opt/homebrew/lib/python3.11/site-packages (from TTS) (4.50.3)
# Requirement already satisfied: encodec>=0.1.1 in /opt/homebrew/lib/python3.11/site-packages (from TTS) (0.1.1)
# Collecting unidecode>=1.3.2 (from TTS)
#   Obtaining dependency information for unidecode>=1.3.2 from https://files.pythonhosted.org/packages/8f/b7/559f59d57d18b44c6d1250d2eeaa676e028b9c527431f5d0736478a73ba1/Unidecode-1.4.0-py3-none-any.whl.metadata
#   Downloading Unidecode-1.4.0-py3-none-any.whl.metadata (13 kB)
# Collecting num2words (from TTS)
#   Obtaining dependency information for num2words from https://files.pythonhosted.org/packages/d6/5b/545e9267a1cc080c8a1be2746113a063e34bcdd0f5173fd665a5c13cb234/num2words-0.5.14-py3-none-any.whl.metadata
#   Using cached num2words-0.5.14-py3-none-any.whl.metadata (13 kB)
# Collecting spacy[ja]>=3 (from TTS)
#   Obtaining dependency information for spacy[ja]>=3 from https://files.pythonhosted.org/packages/4e/2a/83ca9b4d0a2b31adcf0ced49fa667212d12958f75d4e238618a60eb50b10/spacy-3.8.11-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading spacy-3.8.11-cp311-cp311-macosx_11_0_arm64.whl.metadata (27 kB)
# Requirement already satisfied: numpy>=1.24.3 in /opt/homebrew/lib/python3.11/site-packages (from TTS) (1.26.4)
# Requirement already satisfied: numba>=0.57.0 in /opt/homebrew/lib/python3.11/site-packages (from TTS) (0.61.0)
# Requirement already satisfied: Babel<3.0.0,>=2.8.0 in /opt/homebrew/lib/python3.11/site-packages (from gruut[de,es,fr]==2.2.3->TTS) (2.15.0)
# Collecting dateparser~=1.1.0 (from gruut[de,es,fr]==2.2.3->TTS)
#   Obtaining dependency information for dateparser~=1.1.0 from https://files.pythonhosted.org/packages/7a/bf/457ed5be028fb235f8f5ad40b5ddbf67023e0017090ea324d0fe6239a73c/dateparser-1.1.8-py2.py3-none-any.whl.metadata
#   Using cached dateparser-1.1.8-py2.py3-none-any.whl.metadata (27 kB)
# Collecting gruut-ipa<1.0,>=0.12.0 (from gruut[de,es,fr]==2.2.3->TTS)
#   Using cached gruut_ipa-0.13.0-py3-none-any.whl
# Collecting gruut-lang-en~=2.0.0 (from gruut[de,es,fr]==2.2.3->TTS)
#   Using cached gruut_lang_en-2.0.1-py3-none-any.whl
# Collecting jsonlines~=1.2.0 (from gruut[de,es,fr]==2.2.3->TTS)
#   Obtaining dependency information for jsonlines~=1.2.0 from https://files.pythonhosted.org/packages/4f/9a/ab96291470e305504aa4b7a2e0ec132e930da89eb3ca7a82fbe03167c131/jsonlines-1.2.0-py2.py3-none-any.whl.metadata
#   Using cached jsonlines-1.2.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting networkx<3.0.0,>=2.5.0 (from gruut[de,es,fr]==2.2.3->TTS)
#   Obtaining dependency information for networkx<3.0.0,>=2.5.0 from https://files.pythonhosted.org/packages/42/31/d2f89f1ae42718f8c8a9e440ebe38d7d5fe1e0d9eb9178ce779e365b3ab0/networkx-2.8.8-py3-none-any.whl.metadata
#   Using cached networkx-2.8.8-py3-none-any.whl.metadata (5.1 kB)
# Collecting python-crfsuite~=0.9.7 (from gruut[de,es,fr]==2.2.3->TTS)
#   Obtaining dependency information for python-crfsuite~=0.9.7 from https://files.pythonhosted.org/packages/bc/32/743048adf41ba3ebc4d82deed5d4a336164dc0066ef83b28d2a4b1979d66/python_crfsuite-0.9.11-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Using cached python_crfsuite-0.9.11-cp311-cp311-macosx_11_0_arm64.whl.metadata (4.3 kB)
# Collecting gruut-lang-de~=2.0.0 (from gruut[de,es,fr]==2.2.3->TTS)
#   Using cached gruut_lang_de-2.0.1-py3-none-any.whl
# Collecting gruut-lang-es~=2.0.0 (from gruut[de,es,fr]==2.2.3->TTS)
#   Downloading gruut_lang_es-2.0.1.tar.gz (31.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.4/31.4 MB 10.5 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Collecting gruut-lang-fr~=2.0.0 (from gruut[de,es,fr]==2.2.3->TTS)
#   Downloading gruut_lang_fr-2.0.2.tar.gz (10.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 6.3 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Collecting boto3 (from bark)
#   Obtaining dependency information for boto3 from https://files.pythonhosted.org/packages/00/25/9ae819385aad79f524859f7179cecf8ac019b63ac8f150c51b250967f6db/boto3-1.42.4-py3-none-any.whl.metadata
#   Downloading boto3-1.42.4-py3-none-any.whl.metadata (6.8 kB)
# Collecting funcy (from bark)
#   Obtaining dependency information for funcy from https://files.pythonhosted.org/packages/d5/08/c2409cb01d5368dcfedcbaffa7d044cc8957d57a9d0855244a5eb4709d30/funcy-2.0-py2.py3-none-any.whl.metadata
#   Downloading funcy-2.0-py2.py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: huggingface-hub>=0.14.1 in /opt/homebrew/lib/python3.11/site-packages (from bark) (0.29.3)
# Requirement already satisfied: tokenizers in /opt/homebrew/lib/python3.11/site-packages (from bark) (0.21.1)
# Requirement already satisfied: cffi>=1.0 in /opt/homebrew/lib/python3.11/site-packages (from soundfile) (1.16.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp>=3.8.1->TTS) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp>=3.8.1->TTS) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp>=3.8.1->TTS) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp>=3.8.1->TTS) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp>=3.8.1->TTS) (1.9.2)
# Requirement already satisfied: pycparser in /opt/homebrew/lib/python3.11/site-packages (from cffi>=1.0->soundfile) (2.22)
# Requirement already satisfied: Werkzeug>=2.2.2 in /opt/homebrew/lib/python3.11/site-packages (from flask>=2.0.1->TTS) (2.2.3)
# Requirement already satisfied: Jinja2>=3.0 in /opt/homebrew/lib/python3.11/site-packages (from flask>=2.0.1->TTS) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in /opt/homebrew/lib/python3.11/site-packages (from flask>=2.0.1->TTS) (2.1.2)
# Requirement already satisfied: click>=8.0 in /opt/homebrew/lib/python3.11/site-packages (from flask>=2.0.1->TTS) (8.1.3)
# Requirement already satisfied: filelock in /opt/homebrew/lib/python3.11/site-packages (from huggingface-hub>=0.14.1->bark) (3.17.0)
# Requirement already satisfied: requests in /opt/homebrew/lib/python3.11/site-packages (from huggingface-hub>=0.14.1->bark) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/homebrew/lib/python3.11/site-packages (from huggingface-hub>=0.14.1->bark) (4.15.0)
# Requirement already satisfied: more_itertools>=8.5.0 in /opt/homebrew/lib/python3.11/site-packages (from inflect>=5.6.0->TTS) (10.2.0)
# Collecting typeguard>=4.0.1 (from inflect>=5.6.0->TTS)
#   Obtaining dependency information for typeguard>=4.0.1 from https://files.pythonhosted.org/packages/1b/a9/e3aee762739c1d7528da1c3e06d518503f8b6c439c35549b53735ba52ead/typeguard-4.4.4-py3-none-any.whl.metadata
#   Downloading typeguard-4.4.4-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: audioread>=2.1.9 in /opt/homebrew/lib/python3.11/site-packages (from librosa>=0.10.0->TTS) (3.0.1)
# Requirement already satisfied: joblib>=1.0 in /opt/homebrew/lib/python3.11/site-packages (from librosa>=0.10.0->TTS) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /opt/homebrew/lib/python3.11/site-packages (from librosa>=0.10.0->TTS) (4.4.2)
# Requirement already satisfied: pooch>=1.1 in /opt/homebrew/lib/python3.11/site-packages (from librosa>=0.10.0->TTS) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /opt/homebrew/lib/python3.11/site-packages (from librosa>=0.10.0->TTS) (0.5.0.post1)
# Requirement already satisfied: lazy_loader>=0.1 in /opt/homebrew/lib/python3.11/site-packages (from librosa>=0.10.0->TTS) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /opt/homebrew/lib/python3.11/site-packages (from librosa>=0.10.0->TTS) (1.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib>=3.7.0->TTS) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib>=3.7.0->TTS) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib>=3.7.0->TTS) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib>=3.7.0->TTS) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib>=3.7.0->TTS) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib>=3.7.0->TTS) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib>=3.7.0->TTS) (2.8.2)
# Collecting docopt>=0.6.2 (from num2words->TTS)
#   Using cached docopt-0.6.2-py2.py3-none-any.whl
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /opt/homebrew/lib/python3.11/site-packages (from numba>=0.57.0->TTS) (0.44.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/lib/python3.11/site-packages (from pandas<2.0,>=1.4->TTS) (2024.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/homebrew/lib/python3.11/site-packages (from scikit-learn>=1.3.0->TTS) (3.5.0)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy[ja]>=3->TTS)
#   Obtaining dependency information for spacy-legacy<3.1.0,>=3.0.11 from https://files.pythonhosted.org/packages/c3/55/12e842c70ff8828e34e543a2c7176dac4da006ca6901c9e8b43efab8bc6b/spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy[ja]>=3->TTS)
#   Obtaining dependency information for spacy-loggers<2.0.0,>=1.0.0 from https://files.pythonhosted.org/packages/33/78/d1a1a026ef3af911159398c939b1509d5c36fe524c7b644f34a5146c4e16/spacy_loggers-1.0.5-py3-none-any.whl.metadata
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy[ja]>=3->TTS)
#   Obtaining dependency information for murmurhash<1.1.0,>=0.28.0 from https://files.pythonhosted.org/packages/e6/53/a936f577d35b245d47b310f29e5e9f09fcac776c8c992f1ab51a9fb0cee2/murmurhash-1.0.15-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading murmurhash-1.0.15-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.3 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy[ja]>=3->TTS)
#   Obtaining dependency information for cymem<2.1.0,>=2.0.2 from https://files.pythonhosted.org/packages/81/13/57f936fc08551323aab3f92ff6b7f4d4b89d5b4e495c870a67cb8d279757/cymem-2.0.13-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading cymem-2.0.13-cp311-cp311-macosx_11_0_arm64.whl.metadata (9.7 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy[ja]>=3->TTS)
#   Obtaining dependency information for preshed<3.1.0,>=3.0.2 from https://files.pythonhosted.org/packages/8c/cb/685ca57ca6e438345b3f6c20226705a0e056a3de399a5bf8a9ee89b3dd2b/preshed-3.0.12-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading preshed-3.0.12-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.5 kB)
# Collecting thinc<8.4.0,>=8.3.4 (from spacy[ja]>=3->TTS)
#   Obtaining dependency information for thinc<8.4.0,>=8.3.4 from https://files.pythonhosted.org/packages/f0/ba/e0edcc84014bdde1bc9a082408279616a061566a82b5e3b90b9e64f33c1b/thinc-8.3.10-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading thinc-8.3.10-cp311-cp311-macosx_11_0_arm64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy[ja]>=3->TTS)
#   Obtaining dependency information for wasabi<1.2.0,>=0.9.1 from https://files.pythonhosted.org/packages/06/7c/34330a89da55610daa5f245ddce5aab81244321101614751e7537f125133/wasabi-1.1.3-py3-none-any.whl.metadata
#   Downloading wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.4.3 (from spacy[ja]>=3->TTS)
#   Obtaining dependency information for srsly<3.0.0,>=2.4.3 from https://files.pythonhosted.org/packages/a1/e7/587bcade6b72f919133e587edf60e06039d88049aef9015cd0bdea8df189/srsly-2.5.2-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading srsly-2.5.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (19 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy[ja]>=3->TTS)
#   Obtaining dependency information for catalogue<2.1.0,>=2.0.6 from https://files.pythonhosted.org/packages/9e/96/d32b941a501ab566a16358d68b6eb4e4acc373fab3c3c4d7d9e649f7b4bb/catalogue-2.0.10-py3-none-any.whl.metadata
#   Downloading catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<0.5.0,>=0.4.2 (from spacy[ja]>=3->TTS)
#   Obtaining dependency information for weasel<0.5.0,>=0.4.2 from https://files.pythonhosted.org/packages/a4/74/a148b41572656904a39dfcfed3f84dd1066014eed94e209223ae8e9d088d/weasel-0.4.3-py3-none-any.whl.metadata
#   Downloading weasel-0.4.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting typer-slim<1.0.0,>=0.3.0 (from spacy[ja]>=3->TTS)
#   Obtaining dependency information for typer-slim<1.0.0,>=0.3.0 from https://files.pythonhosted.org/packages/5e/dd/5cbf31f402f1cc0ab087c94d4669cfa55bd1e818688b910631e131d74e75/typer_slim-0.20.0-py3-none-any.whl.metadata
#   Downloading typer_slim-0.20.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /opt/homebrew/lib/python3.11/site-packages (from spacy[ja]>=3->TTS) (2.10.6)
# Requirement already satisfied: setuptools in /opt/homebrew/lib/python3.11/site-packages (from spacy[ja]>=3->TTS) (68.1.2)
# Collecting sudachipy!=0.6.1,>=0.5.2 (from spacy[ja]>=3->TTS)
#   Obtaining dependency information for sudachipy!=0.6.1,>=0.5.2 from https://files.pythonhosted.org/packages/8a/2e/3694b72d52ee6d3c0a55d88f84ea34536acfb6c49a089c346fee83a2f8ef/SudachiPy-0.6.10-cp311-cp311-macosx_10_12_universal2.whl.metadata
#   Downloading SudachiPy-0.6.10-cp311-cp311-macosx_10_12_universal2.whl.metadata (12 kB)
# Collecting sudachidict_core>=20211220 (from spacy[ja]>=3->TTS)
#   Obtaining dependency information for sudachidict_core>=20211220 from https://files.pythonhosted.org/packages/7c/d4/871635b678cc2cd624c3f0a26dedda4789e8a1dfaf10b7c0f517654c368d/sudachidict_core-20251022-py3-none-any.whl.metadata
#   Downloading sudachidict_core-20251022-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: sympy==1.13.1 in /opt/homebrew/lib/python3.11/site-packages (from torch>=2.1->TTS) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/homebrew/lib/python3.11/site-packages (from sympy==1.13.1->torch>=2.1->TTS) (1.3.0)
# Requirement already satisfied: psutil in /Users/velimirhlebnikov/Library/Python/3.11/lib/python/site-packages (from trainer>=0.0.32->TTS) (5.9.8)
# Requirement already satisfied: tensorboard in /opt/homebrew/lib/python3.11/site-packages (from trainer>=0.0.32->TTS) (2.15.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/homebrew/lib/python3.11/site-packages (from transformers>=4.33.0->TTS) (2023.10.3)
# Requirement already satisfied: safetensors>=0.4.3 in /opt/homebrew/lib/python3.11/site-packages (from transformers>=4.33.0->TTS) (0.5.3)
# Requirement already satisfied: pynndescent>=0.5 in /opt/homebrew/lib/python3.11/site-packages (from umap-learn>=0.5.1->TTS) (0.5.13)
# Collecting botocore<1.43.0,>=1.42.4 (from boto3->bark)
#   Obtaining dependency information for botocore<1.43.0,>=1.42.4 from https://files.pythonhosted.org/packages/9b/a2/7b50f12a9c5a33cd85a5f23fdf78a0cbc445c0245c16051bb627f328be06/botocore-1.42.4-py3-none-any.whl.metadata
#   Downloading botocore-1.42.4-py3-none-any.whl.metadata (5.9 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3->bark)
#   Obtaining dependency information for jmespath<2.0.0,>=0.7.1 from https://files.pythonhosted.org/packages/31/b4/b9b800c45527aadd64d5b442f9b932b00648617eb5d63d2c7a6587b7cafc/jmespath-1.0.1-py3-none-any.whl.metadata
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.17.0,>=0.16.0 (from boto3->bark)
#   Obtaining dependency information for s3transfer<0.17.0,>=0.16.0 from https://files.pythonhosted.org/packages/fc/51/727abb13f44c1fcf6d145979e1535a35794db0f6e450a0cb46aa24732fe2/s3transfer-0.16.0-py3-none-any.whl.metadata
#   Downloading s3transfer-0.16.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /opt/homebrew/lib/python3.11/site-packages (from botocore<1.43.0,>=1.42.4->boto3->bark) (1.26.15)
# Collecting tzlocal (from dateparser~=1.1.0->gruut[de,es,fr]==2.2.3->TTS)
#   Obtaining dependency information for tzlocal from https://files.pythonhosted.org/packages/c2/14/e2a54fabd4f08cd7af1c07030603c3356b74da07f7cc056e600436edfa17/tzlocal-5.3.1-py3-none-any.whl.metadata
#   Using cached tzlocal-5.3.1-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/lib/python3.11/site-packages (from Jinja2>=3.0->flask>=2.0.1->TTS) (2.1.2)
# Requirement already satisfied: six in /opt/homebrew/lib/python3.11/site-packages (from jsonlines~=1.2.0->gruut[de,es,fr]==2.2.3->TTS) (1.16.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /Users/velimirhlebnikov/Library/Python/3.11/lib/python/site-packages (from pooch>=1.1->librosa>=0.10.0->TTS) (4.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/homebrew/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy[ja]>=3->TTS) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /opt/homebrew/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy[ja]>=3->TTS) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/lib/python3.11/site-packages (from requests->huggingface-hub>=0.14.1->bark) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/lib/python3.11/site-packages (from requests->huggingface-hub>=0.14.1->bark) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/lib/python3.11/site-packages (from requests->huggingface-hub>=0.14.1->bark) (2024.12.14)
# Collecting blis<1.4.0,>=1.3.0 (from thinc<8.4.0,>=8.3.4->spacy[ja]>=3->TTS)
#   Obtaining dependency information for blis<1.4.0,>=1.3.0 from https://files.pythonhosted.org/packages/83/5a/3437009282f23684ecd3963a8b034f9307cdd2bf4484972e5a6b096bf9ac/blis-1.3.3-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading blis-1.3.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (7.5 kB)
# Collecting confection<1.0.0,>=0.0.1 (from thinc<8.4.0,>=8.3.4->spacy[ja]>=3->TTS)
#   Obtaining dependency information for confection<1.0.0,>=0.0.1 from https://files.pythonhosted.org/packages/0c/00/3106b1854b45bd0474ced037dfe6b73b90fe68a68968cef47c23de3d43d2/confection-0.1.5-py3-none-any.whl.metadata
#   Downloading confection-0.1.5-py3-none-any.whl.metadata (19 kB)
# Collecting cloudpathlib<1.0.0,>=0.7.0 (from weasel<0.5.0,>=0.4.2->spacy[ja]>=3->TTS)
#   Obtaining dependency information for cloudpathlib<1.0.0,>=0.7.0 from https://files.pythonhosted.org/packages/ae/8a/c4bb04426d608be4a3171efa2e233d2c59a5c8937850c10d098e126df18e/cloudpathlib-0.23.0-py3-none-any.whl.metadata
#   Downloading cloudpathlib-0.23.0-py3-none-any.whl.metadata (16 kB)
# Collecting smart-open<8.0.0,>=5.2.1 (from weasel<0.5.0,>=0.4.2->spacy[ja]>=3->TTS)
#   Obtaining dependency information for smart-open<8.0.0,>=5.2.1 from https://files.pythonhosted.org/packages/ad/95/bc978be7ea0babf2fb48a414b6afaad414c6a9e8b1eafc5b8a53c030381a/smart_open-7.5.0-py3-none-any.whl.metadata
#   Downloading smart_open-7.5.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: absl-py>=0.4 in /opt/homebrew/lib/python3.11/site-packages (from tensorboard->trainer>=0.0.32->TTS) (2.0.0)
# Requirement already satisfied: grpcio>=1.48.2 in /opt/homebrew/lib/python3.11/site-packages (from tensorboard->trainer>=0.0.32->TTS) (1.60.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /opt/homebrew/lib/python3.11/site-packages (from tensorboard->trainer>=0.0.32->TTS) (2.25.2)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /opt/homebrew/lib/python3.11/site-packages (from tensorboard->trainer>=0.0.32->TTS) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /opt/homebrew/lib/python3.11/site-packages (from tensorboard->trainer>=0.0.32->TTS) (3.5.1)
# Requirement already satisfied: protobuf<4.24,>=3.19.6 in /opt/homebrew/lib/python3.11/site-packages (from tensorboard->trainer>=0.0.32->TTS) (4.21.12)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/homebrew/lib/python3.11/site-packages (from tensorboard->trainer>=0.0.32->TTS) (0.7.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/homebrew/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard->trainer>=0.0.32->TTS) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/homebrew/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard->trainer>=0.0.32->TTS) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/homebrew/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard->trainer>=0.0.32->TTS) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/homebrew/lib/python3.11/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard->trainer>=0.0.32->TTS) (1.3.1)
# Requirement already satisfied: wrapt in /opt/homebrew/lib/python3.11/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.4.2->spacy[ja]>=3->TTS) (1.14.1)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /opt/homebrew/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->trainer>=0.0.32->TTS) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/homebrew/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard->trainer>=0.0.32->TTS) (3.2.2)
# Downloading bark-0.1.5-py3-none-any.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 1.8 MB/s eta 0:00:0000:0100:01
# Downloading anyascii-0.3.3-py3-none-any.whl (345 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.1/345.1 kB 2.3 MB/s eta 0:00:00a 0:00:01
# Using cached coqpit-0.0.17-py3-none-any.whl (13 kB)
# Using cached g2pkk-0.1.2-py3-none-any.whl (25 kB)
# Downloading inflect-7.5.0-py3-none-any.whl (35 kB)
# Using cached num2words-0.5.14-py3-none-any.whl (163 kB)
# Downloading pandas-1.5.3-cp311-cp311-macosx_11_0_arm64.whl (10.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 5.0 MB/s eta 0:00:0000:0100:01m
# Using cached pysbd-0.3.4-py3-none-any.whl (71 kB)
# Downloading trainer-0.0.36-py3-none-any.whl (51 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.2/51.2 kB 3.8 MB/s eta 0:00:00
# Downloading Unidecode-1.4.0-py3-none-any.whl (235 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.8/235.8 kB 6.1 MB/s eta 0:00:0000:01
# Downloading bangla-0.0.5-py3-none-any.whl (5.1 kB)
# Downloading bnunicodenormalizer-0.1.7-py3-none-any.whl (23 kB)
# Downloading boto3-1.42.4-py3-none-any.whl (140 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 kB 6.6 MB/s eta 0:00:00
# Downloading funcy-2.0-py2.py3-none-any.whl (30 kB)
# Downloading hangul_romanize-0.1.0-py3-none-any.whl (4.6 kB)
# Using cached jamo-0.4.1-py3-none-any.whl (9.5 kB)
# Downloading nltk-3.9.2-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 6.5 MB/s eta 0:00:00a 0:00:01
# Downloading pypinyin-0.55.0-py2.py3-none-any.whl (840 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 840.2/840.2 kB 8.7 MB/s eta 0:00:00a 0:00:01
# Downloading botocore-1.42.4-py3-none-any.whl (14.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.5/14.5 MB 8.8 MB/s eta 0:00:0000:0100:01
# Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Downloading cymem-2.0.13-cp311-cp311-macosx_11_0_arm64.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.1/43.1 kB 3.0 MB/s eta 0:00:00
# Using cached dateparser-1.1.8-py2.py3-none-any.whl (293 kB)
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Using cached jsonlines-1.2.0-py2.py3-none-any.whl (7.6 kB)
# Downloading murmurhash-1.0.15-cp311-cp311-macosx_11_0_arm64.whl (27 kB)
# Using cached networkx-2.8.8-py3-none-any.whl (2.0 MB)
# Downloading preshed-3.0.12-cp311-cp311-macosx_11_0_arm64.whl (124 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.5/124.5 kB 453.0 kB/s eta 0:00:000:00:01
# Using cached python_crfsuite-0.9.11-cp311-cp311-macosx_11_0_arm64.whl (319 kB)
# Downloading s3transfer-0.16.0-py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 3.4 MB/s eta 0:00:00
# Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Downloading srsly-2.5.2-cp311-cp311-macosx_11_0_arm64.whl (653 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 653.1/653.1 kB 1.2 MB/s eta 0:00:00a 0:00:01
# Downloading sudachidict_core-20251022-py3-none-any.whl (72.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.2/72.2 MB 6.8 MB/s eta 0:00:0000:0100:01m
# Downloading SudachiPy-0.6.10-cp311-cp311-macosx_10_12_universal2.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 5.8 MB/s eta 0:00:00a 0:00:01
# Downloading thinc-8.3.10-cp311-cp311-macosx_11_0_arm64.whl (770 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 770.6/770.6 kB 7.1 MB/s eta 0:00:00a 0:00:01
# Downloading typeguard-4.4.4-py3-none-any.whl (34 kB)
# Downloading typer_slim-0.20.0-py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.1/47.1 kB 2.8 MB/s eta 0:00:00
# Downloading wasabi-1.1.3-py3-none-any.whl (27 kB)
# Downloading weasel-0.4.3-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.8/50.8 kB 4.8 MB/s eta 0:00:00
# Downloading spacy-3.8.11-cp311-cp311-macosx_11_0_arm64.whl (6.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 8.3 MB/s eta 0:00:0000:0100:01m
# Downloading blis-1.3.3-cp311-cp311-macosx_11_0_arm64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 4.4 MB/s eta 0:00:00a 0:00:01
# Downloading cloudpathlib-0.23.0-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 718.4 kB/s eta 0:00:00 0:00:01
# Downloading confection-0.1.5-py3-none-any.whl (35 kB)
# Downloading smart_open-7.5.0-py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.9/63.9 kB 4.7 MB/s eta 0:00:00
# Using cached tzlocal-5.3.1-py3-none-any.whl (18 kB)
# Building wheels for collected packages: TTS, bnnumerizer, gruut-lang-es, gruut-lang-fr
#   Building wheel for TTS (pyproject.toml) ... done
#   Created wheel for TTS: filename=TTS-0.22.0-cp311-cp311-macosx_13_0_arm64.whl size=903600 sha256=ed73558fc5cfb1696375d4155630401d3ecb386164665d90e99a959d41f08b0d
#   Stored in directory: /Users/velimirhlebnikov/Library/Caches/pip/wheels/2a/54/92/3ba43806fe20a11a7774184345f0e89498327b94503dc29bb1
#   Building wheel for bnnumerizer (setup.py) ... done
#   Created wheel for bnnumerizer: filename=bnnumerizer-0.0.2-py3-none-any.whl size=5259 sha256=95399c4ffe7cb9831b10756e2399bd3e6f61ba25016335d7c949dcb089c3776f
#   Stored in directory: /Users/velimirhlebnikov/Library/Caches/pip/wheels/9e/b9/e3/4145416693824818c0b931988a692676ecd4bbf2ea41d1eedd
#   Building wheel for gruut-lang-es (setup.py) ... done
#   Created wheel for gruut-lang-es: filename=gruut_lang_es-2.0.1-py3-none-any.whl size=32173927 sha256=e6ea0baca265ab98ec3d6453c51a159e73d47f2365efc62b0b21f99ebded3585
#   Stored in directory: /Users/velimirhlebnikov/Library/Caches/pip/wheels/c8/eb/59/30b5d15e56347e595f613036cbea0f807ad9621c75cd75d912
#   Building wheel for gruut-lang-fr (setup.py) ... done
#   Created wheel for gruut-lang-fr: filename=gruut_lang_fr-2.0.2-py3-none-any.whl size=10968767 sha256=44e097d54b8ef44d6a51a73e56d66b20344a51157ca330abdf7b1e62b177700f
#   Stored in directory: /Users/velimirhlebnikov/Library/Caches/pip/wheels/e0/e7/a0/7c416a3eeaa94ca71bf7bcbc6289cced2263d8ba35e82444bb
# Successfully built TTS bnnumerizer gruut-lang-es gruut-lang-fr
# Installing collected packages: sudachipy, jieba, jamo, hangul-romanize, gruut-lang-fr, gruut-lang-es, gruut-lang-en, gruut-lang-de, funcy, docopt, bnunicodenormalizer, bnnumerizer, bangla, wasabi, unidecode, tzlocal, typer-slim, typeguard, sudachidict_core, spacy-loggers, spacy-legacy, smart-open, python-crfsuite, pysbd, pypinyin, num2words, nltk, networkx, murmurhash, jsonlines, jmespath, gruut-ipa, cymem, coqpit, cloudpathlib, catalogue, blis, anyascii, srsly, preshed, pandas, inflect, g2pkk, dateparser, botocore, s3transfer, gruut, confection, weasel, thinc, boto3, trainer, spacy, bark, TTS
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.2.1
#     Uninstalling networkx-3.2.1:
#       Successfully uninstalled networkx-3.2.1
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.1
#     Uninstalling pandas-2.2.1:
#       Successfully uninstalled pandas-2.2.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# xarray 2025.9.0 requires pandas>=2.2, but you have pandas 1.5.3 which is incompatible.
# Successfully installed TTS-0.22.0 anyascii-0.3.3 bangla-0.0.5 bark-0.1.5 blis-1.3.3 bnnumerizer-0.0.2 bnunicodenormalizer-0.1.7 boto3-1.42.4 botocore-1.42.4 catalogue-2.0.10 cloudpathlib-0.23.0 confection-0.1.5 coqpit-0.0.17 cymem-2.0.13 dateparser-1.1.8 docopt-0.6.2 funcy-2.0 g2pkk-0.1.2 gruut-2.2.3 gruut-ipa-0.13.0 gruut-lang-de-2.0.1 gruut-lang-en-2.0.1 gruut-lang-es-2.0.1 gruut-lang-fr-2.0.2 hangul-romanize-0.1.0 inflect-7.5.0 jamo-0.4.1 jieba-0.42.1 jmespath-1.0.1 jsonlines-1.2.0 murmurhash-1.0.15 networkx-2.8.8 nltk-3.9.2 num2words-0.5.14 pandas-1.5.3 preshed-3.0.12 pypinyin-0.55.0 pysbd-0.3.4 python-crfsuite-0.9.11 s3transfer-0.16.0 smart-open-7.5.0 spacy-3.8.11 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.5.2 sudachidict_core-20251022 sudachipy-0.6.10 thinc-8.3.10 trainer-0.0.36 typeguard-4.4.4 typer-slim-0.20.0 tzlocal-5.3.1 unidecode-1.4.0 wasabi-1.1.3 weasel-0.4.3
#
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: speechbrain in /opt/homebrew/lib/python3.11/site-packages (0.5.16)
# Requirement already satisfied: torchaudio in /opt/homebrew/lib/python3.11/site-packages (2.6.0)
# Requirement already satisfied: hyperpyyaml in /opt/homebrew/lib/python3.11/site-packages (from speechbrain) (1.2.2)
# Requirement already satisfied: joblib in /opt/homebrew/lib/python3.11/site-packages (from speechbrain) (1.4.2)
# Requirement already satisfied: numpy in /opt/homebrew/lib/python3.11/site-packages (from speechbrain) (1.26.4)
# Requirement already satisfied: packaging in /opt/homebrew/lib/python3.11/site-packages (from speechbrain) (25.0)
# Requirement already satisfied: scipy in /opt/homebrew/lib/python3.11/site-packages (from speechbrain) (1.11.4)
# Requirement already satisfied: sentencepiece in /opt/homebrew/lib/python3.11/site-packages (from speechbrain) (0.2.0)
# Requirement already satisfied: torch>=1.9 in /opt/homebrew/lib/python3.11/site-packages (from speechbrain) (2.6.0)
# Requirement already satisfied: tqdm in /opt/homebrew/lib/python3.11/site-packages (from speechbrain) (4.67.1)
# Requirement already satisfied: huggingface-hub in /opt/homebrew/lib/python3.11/site-packages (from speechbrain) (0.29.3)
# Requirement already satisfied: filelock in /opt/homebrew/lib/python3.11/site-packages (from torch>=1.9->speechbrain) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/homebrew/lib/python3.11/site-packages (from torch>=1.9->speechbrain) (4.15.0)
# Requirement already satisfied: networkx in /opt/homebrew/lib/python3.11/site-packages (from torch>=1.9->speechbrain) (2.8.8)
# Requirement already satisfied: jinja2 in /opt/homebrew/lib/python3.11/site-packages (from torch>=1.9->speechbrain) (3.1.2)
# Requirement already satisfied: fsspec in /opt/homebrew/lib/python3.11/site-packages (from torch>=1.9->speechbrain) (2024.5.0)
# Requirement already satisfied: sympy==1.13.1 in /opt/homebrew/lib/python3.11/site-packages (from torch>=1.9->speechbrain) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/homebrew/lib/python3.11/site-packages (from sympy==1.13.1->torch>=1.9->speechbrain) (1.3.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/homebrew/lib/python3.11/site-packages (from huggingface-hub->speechbrain) (6.0.2)
# Requirement already satisfied: requests in /opt/homebrew/lib/python3.11/site-packages (from huggingface-hub->speechbrain) (2.32.3)
# Requirement already satisfied: ruamel.yaml>=0.17.28 in /opt/homebrew/lib/python3.11/site-packages (from hyperpyyaml->speechbrain) (0.18.16)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /opt/homebrew/lib/python3.11/site-packages (from ruamel.yaml>=0.17.28->hyperpyyaml->speechbrain) (0.2.15)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/lib/python3.11/site-packages (from jinja2->torch>=1.9->speechbrain) (2.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/lib/python3.11/site-packages (from requests->huggingface-hub->speechbrain) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/lib/python3.11/site-packages (from requests->huggingface-hub->speechbrain) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/lib/python3.11/site-packages (from requests->huggingface-hub->speechbrain) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/lib/python3.11/site-packages (from requests->huggingface-hub->speechbrain) (2024.12.14)
#
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import csv
import os
import tempfile
import time
from pathlib import Path
import statistics

import psutil
import torch

corpus_path = "corpus/en_corpus_10.txt"
WARMUP_TEXT = "Hello"
BENCHMARK_TEXT = "Тестовая фраза для синтеза."


def get_corpus(path: str):
    if not os.path.exists(path):
        raise FileNotFoundError("corpus not found")

    with open(path, "r") as file:
        samples = [x.strip() for x in file.readlines()]

    return [sample for sample in samples if sample]


corpus = get_corpus(corpus_path)
device = "cuda" if torch.cuda.is_available() else "cpu"
print("Device: ", device)
model_names = ["bark", "glow_tts", "vits", "xtts", "whisper-speech"]
stats = {name: {"report": {}, "deltas": []} for name in model_names}

reports_dir = Path("reports")
reports_dir.mkdir(parents=True, exist_ok=True)
report_csv_path = reports_dir / "lab4_report.csv"
report_rows = []


def create_temp_wav(prefix: str) -> str:
    tmp = tempfile.NamedTemporaryFile(prefix=f"{prefix}_", suffix=".wav", delete=False)
    path = tmp.name
    tmp.close()
    return path


def summarize_deltas(deltas):
    if not deltas:
        return {
            "num_runs": 0,
            "mean_runtime_s": None,
            "median_runtime_s": None,
            "std_runtime_s": None,
            "min_runtime_s": None,
            "max_runtime_s": None,
        }

    summary = {
        "num_runs": len(deltas),
        "mean_runtime_s": statistics.mean(deltas),
        "median_runtime_s": statistics.median(deltas),
        "std_runtime_s": statistics.pstdev(deltas) if len(deltas) > 1 else 0.0,
        "min_runtime_s": min(deltas),
        "max_runtime_s": max(deltas),
    }

    return summary


def record_run(model_name, audio_file, duration, model_report):
    row = {
        "audio_file": audio_file,
        "model": model_name,
        "inference_time_s": duration,
    }

    for key, value in (model_report or {}).items():
        if key == "model_name":
            continue
        row[key] = value

    report_rows.append(row)


def save_report(rows, path):
    if not rows:
        print("Report was not generated: no successful synthesis runs.")
        return

    fieldnames = ["audio_file", "model", "inference_time_s"]
    for row in rows:
        for key in row.keys():
            if key not in fieldnames:
                fieldnames.append(key)

    with open(path, "w", newline="") as csv_file:
        writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
        writer.writeheader()
        writer.writerows(rows)

    print(f"Saved report to {path} ({len(rows)} rows).")


def evaluate_tts_model(
    name,
    synth_fn,
    *,
    warmup_kwargs=None,
    benchmark_kwargs=None,
    model_obj=None,
):
    warmup_kwargs = dict(warmup_kwargs or {})
    benchmark_kwargs = dict(benchmark_kwargs or {})

    def _run(call_kwargs):
        kwargs = dict(call_kwargs) if call_kwargs else {}
        tmp_path = kwargs.get("file_path")
        try:
            synth_fn(**kwargs)
        finally:
            if tmp_path and os.path.exists(tmp_path):
                try:
                    os.remove(tmp_path)
                except OSError:
                    pass

    if torch.cuda.is_available() and hasattr(torch.cuda, "reset_peak_memory_stats"):
        torch.cuda.reset_peak_memory_stats()

    try:
        _run(warmup_kwargs)
    except Exception as exc:
        print(f"[{name}] Warmup error: {exc}")

    synth_time = None
    start_time = time.time()
    try:
        _run(benchmark_kwargs)
    except Exception as exc:
        print(f"[{name}] Benchmark error: {exc}")
    else:
        synth_time = time.time() - start_time

    model_ref = model_obj or getattr(synth_fn, "__self__", None)

    model_size_mb = None
    if model_ref is not None and hasattr(model_ref, "state_dict"):
        state = model_ref.state_dict()
        total_bytes = sum(t.nelement() * t.element_size() for t in state.values())
        model_size_mb = total_bytes / (1024 * 1024)

    process = psutil.Process(os.getpid())
    mem_mb = process.memory_info().rss / (1024 * 1024)
    cpu_percent = psutil.cpu_percent(interval=0.1)

    gpu_mem = None
    if torch.cuda.is_available():
        gpu_mem = torch.cuda.max_memory_allocated() / (1024 * 1024)

    return {
        "model_name": name,
        "benchmark_synthesis_time_s": synth_time,
        "model_size_mb": model_size_mb,
        "cpu_load_percent": cpu_percent,
        "ram_usage_mb": mem_mb,
        "gpu_usage_mb": gpu_mem,
    }


def timer(func, *args, **kwargs):
    start = time.time()
    func(*args, **kwargs)
    end = time.time()
    return end - start

# %%
# Glow-TTS вместо FastSpeech2
from pathlib import Path
from TTS.api import TTS
import torch

glow_tts_model_name = "glow_tts"   # можешь назвать как хочешь
output_dir = Path("models") / glow_tts_model_name
output_dir.mkdir(parents=True, exist_ok=True)

# инициализация модели (GPU если доступен)
glow_tts = TTS(
    "tts_models/en/ljspeech/glow-tts",
    gpu=torch.cuda.is_available()
)

# отчёт по метрикам (evaluate_tts_model, WARMUP_TEXT, BENCHMARK_TEXT, create_temp_wav должны быть уже определены выше)
glow_report = evaluate_tts_model(
    glow_tts_model_name,
    glow_tts.tts_to_file,
    warmup_kwargs={
        "text": WARMUP_TEXT,
        "file_path": create_temp_wav(f"{glow_tts_model_name}_warmup"),
    },
    benchmark_kwargs={
        "text": BENCHMARK_TEXT,
        "file_path": create_temp_wav(f"{glow_tts_model_name}_bench"),
    },
    model_obj=glow_tts,
)

stats[glow_tts_model_name]["report"] = dict(glow_report)

# прогон по корпусу
for i, sequence in enumerate(corpus):
    output_path = output_dir / f"{i}.wav"
    dt = timer(
        glow_tts.tts_to_file,
        text=sequence,
        file_path=str(output_path),
    )

    stats[glow_tts_model_name]["deltas"].append(dt)
    record_run(glow_tts_model_name, str(output_path), dt, glow_report)

# добавляем агрегированные статистики по времени
stats[glow_tts_model_name]["report"].update(summarize_deltas(stats[glow_tts_model_name]["deltas"]))
# Out:
#  > Downloading model to /Users/velimirhlebnikov/Library/Application Support/tts/tts_models--en--ljspeech--glow-tts
#  17%|█▋        | 58.2M/344M [00:07<00:56, 5.05MiB/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 11
#       8 output_dir.mkdir(parents=True, exist_ok=True)
#      10 # инициализация модели (GPU если доступен)
# ---> 11 glow_tts = TTS(
#      12     "tts_models/en/ljspeech/glow-tts",
#      13     gpu=torch.cuda.is_available()
#      14 )
#      16 # отчёт по метрикам (evaluate_tts_model, WARMUP_TEXT, BENCHMARK_TEXT, create_temp_wav должны быть уже определены выше)
#      17 glow_report = evaluate_tts_model(
#      18     glow_tts_model_name,
#      19     glow_tts.tts_to_file,
#    (...)
#      28     model_obj=glow_tts,
#      29 )
#
# File /opt/homebrew/lib/python3.11/site-packages/TTS/api.py:74, in TTS.__init__(self, model_name, model_path, config_path, vocoder_path, vocoder_config_path, progress_bar, gpu)
#      72 if model_name is not None and len(model_name) > 0:
#      73     if "tts_models" in model_name:
# ---> 74         self.load_tts_model_by_name(model_name, gpu)
#      75     elif "voice_conversion_models" in model_name:
#      76         self.load_vc_model_by_name(model_name, gpu)
#
# File /opt/homebrew/lib/python3.11/site-packages/TTS/api.py:171, in TTS.load_tts_model_by_name(self, model_name, gpu)
#     168 self.synthesizer = None
#     169 self.model_name = model_name
# --> 171 model_path, config_path, vocoder_path, vocoder_config_path, model_dir = self.download_model_by_name(
#     172     model_name
#     173 )
#     175 # init synthesizer
#     176 # None values are fetch from the model
#     177 self.synthesizer = Synthesizer(
#     178     tts_checkpoint=model_path,
#     179     tts_config_path=config_path,
#    (...)
#     187     use_cuda=gpu,
#     188 )
#
# File /opt/homebrew/lib/python3.11/site-packages/TTS/api.py:129, in TTS.download_model_by_name(self, model_name)
#     128 def download_model_by_name(self, model_name: str):
# --> 129     model_path, config_path, model_item = self.manager.download_model(model_name)
#     130     if "fairseq" in model_name or (model_item is not None and isinstance(model_item["model_url"], list)):
#     131         # return model directory if there are multiple files
#     132         # we assume that the model knows how to load itself
#     133         return None, None, None, None, model_path
#
# File /opt/homebrew/lib/python3.11/site-packages/TTS/utils/manage.py:411, in ModelManager.download_model(self, model_name)
#     409         print(f" > {model_name} is already downloaded.")
#     410 else:
# --> 411     self.create_dir_and_download_model(model_name, model_item, output_path)
#     413 # find downloaded files
#     414 output_model_path = output_path
#
# File /opt/homebrew/lib/python3.11/site-packages/TTS/utils/manage.py:345, in ModelManager.create_dir_and_download_model(self, model_name, model_item, output_path)
#     343     self.download_fairseq_model(model_name, output_path)
#     344 elif "github_rls_url" in model_item:
# --> 345     self._download_github_model(model_item, output_path)
#     346 elif "hf_url" in model_item:
#     347     self._download_hf_model(model_item, output_path)
#
# File /opt/homebrew/lib/python3.11/site-packages/TTS/utils/manage.py:233, in ModelManager._download_github_model(self, model_item, output_path)
#     231     self._download_model_files(model_item["github_rls_url"], output_path, self.progress_bar)
#     232 else:
# --> 233     self._download_zip_file(model_item["github_rls_url"], output_path, self.progress_bar)
#
# File /opt/homebrew/lib/python3.11/site-packages/TTS/utils/manage.py:540, in ModelManager._download_zip_file(file_url, output_folder, progress_bar)
#     538 temp_zip_name = os.path.join(output_folder, file_url.split("/")[-1])
#     539 with open(temp_zip_name, "wb") as file:
# --> 540     for data in r.iter_content(block_size):
#     541         if progress_bar:
#     542             ModelManager.tqdm_progress.update(len(data))
#
# File /opt/homebrew/lib/python3.11/site-packages/requests/models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File /opt/homebrew/lib/python3.11/site-packages/urllib3/response.py:628, in HTTPResponse.stream(self, amt, decode_content)
#     626 else:
#     627     while not is_fp_closed(self._fp):
# --> 628         data = self.read(amt=amt, decode_content=decode_content)
#     630         if data:
#     631             yield data
#
# File /opt/homebrew/lib/python3.11/site-packages/urllib3/response.py:567, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     564 fp_closed = getattr(self._fp, "closed", False)
#     566 with self._error_catcher():
# --> 567     data = self._fp_read(amt) if not fp_closed else b""
#     568     if amt is None:
#     569         flush_decoder = True
#
# File /opt/homebrew/lib/python3.11/site-packages/urllib3/response.py:533, in HTTPResponse._fp_read(self, amt)
#     530     return buffer.getvalue()
#     531 else:
#     532     # StringIO doesn't like amt=None
# --> 533     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File /opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:466, in HTTPResponse.read(self, amt)
#     463 if self.length is not None and amt > self.length:
#     464     # clip the read to the "end of response"
#     465     amt = self.length
# --> 466 s = self.fp.read(amt)
#     467 if not s and amt:
#     468     # Ideally, we would raise IncompleteRead if the content-length
#     469     # wasn't satisfied, but it might break compatibility.
#     470     self._close_conn()
#
# File /opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File /opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1311, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1307     if flags != 0:
#    1308         raise ValueError(
#    1309           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1310           self.__class__)
# -> 1311     return self.read(nbytes, buffer)
#    1312 else:
#    1313     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1167, in SSLSocket.read(self, len, buffer)
#    1165 try:
#    1166     if buffer is not None:
# -> 1167         return self._sslobj.read(len, buffer)
#    1168     else:
#    1169         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# VITS
from TTS.api import TTS


vits_tts = TTS("tts_models/en/ljspeech/vits")
vits_tts = vits_tts.to(device)

glow_tts_model_name = "vits"
output_dir = Path("models") / glow_tts_model_name
output_dir.mkdir(parents=True, exist_ok=True)

vits_report = evaluate_tts_model(
    glow_tts_model_name,
    vits_tts.tts_to_file,
    warmup_kwargs={
        "text": WARMUP_TEXT,
        "file_path": create_temp_wav(f"{glow_tts_model_name}_warmup"),
    },
    benchmark_kwargs={
        "text": BENCHMARK_TEXT,
        "file_path": create_temp_wav(f"{glow_tts_model_name}_bench"),
    },
    model_obj=vits_tts,
)

stats[glow_tts_model_name]["report"] = dict(vits_report)

for i, sequence in enumerate(corpus):
    output_path = output_dir / f"{i}.wav"
    dt = timer(
        vits_tts.tts_to_file,
        text=sequence,
        file_path=str(output_path)
    )

    stats[glow_tts_model_name]["deltas"].append(dt)
    record_run(glow_tts_model_name, str(output_path), dt, vits_report)

stats[glow_tts_model_name]["report"].update(summarize_deltas(stats[glow_tts_model_name]["deltas"]))
# Out:
#  > tts_models/en/ljspeech/vits is already downloaded.
#  > Using model: vits
#  > Setting up Audio Processor...
#  | > sample_rate:22050
#  | > resample:False
#  | > num_mels:80
#  | > log_func:np.log10
#  | > min_level_db:0
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:None
#  | > fft_size:1024
#  | > power:None
#  | > preemphasis:0.0
#  | > griffin_lim_iters:None
#  | > signal_norm:None
#  | > symmetric_norm:None
#  | > mel_fmin:0
#  | > mel_fmax:None
#  | > pitch_fmin:None
#  | > pitch_fmax:None
#  | > spec_gain:20.0
#  | > stft_pad_mode:reflect
#  | > max_norm:1.0
#  | > clip_norm:True
#  | > do_trim_silence:False
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:False
#  | > db_level:None
#  | > stats_path:None
#  | > base:10
#  | > hop_length:256
#  | > win_length:1024
#  > Text splitted to sentences.
# ['Hello']
#  > Processing time: 0.1639270782470703
#  > Real-time factor: 0.1785865649875445
#  > Text splitted to sentences.
# ['Тестовая фраза для синтеза.']
# tˈɛː jˈɛː ˈɛs tˈɛː ˈoː vˈɛː ˈæː jˈæː ˈɛf ˈɛɹ ˈæː zˈɛː ˈæː dˈɛː ˈɛl1 jˈæː ˈɛs ˈɪː ˈɛn tˈɛː jˈɛː zˈɛː ˈæː.
#  [!] Character '1' not found in the vocabulary. Discarding it.
#  > Processing time: 0.7815418243408203
#  > Real-time factor: 0.1237291587213892
#  > Text splitted to sentences.
# ['The speech synthesis system should sound natural and intelligible.']
#  > Processing time: 0.5489280223846436
#  > Real-time factor: 0.12028803161851438
#  > Text splitted to sentences.
# ['The model’s performance is important when operating in real time.']
#  > Processing time: 0.7595458030700684
#  > Real-time factor: 0.16071688313464422
#  > Text splitted to sentences.
# ['Neural network methods make it possible to convey complex intonation and emotions.']
#  > Processing time: 0.826469898223877
#  > Real-time factor: 0.1342977041020847
#  > Text splitted to sentences.
# ['Today we are comparing several modern speech synthesis models.']
#  > Processing time: 0.5325400829315186
#  > Real-time factor: 0.10013737232773898
#  > Text splitted to sentences.
# ['The higher the quality of the data, the better the model’s training results.']
#  > Processing time: 0.573091983795166
#  > Real-time factor: 0.11892672642188122
#  > Text splitted to sentences.
# ['Some models use transformers, while others rely on diffusion processes.']
#  > Processing time: 0.681412935256958
#  > Real-time factor: 0.11199429951115031
#  > Text splitted to sentences.
# ['In this laboratory work, we analyze the trade-off between quality and speed.']
#  > Processing time: 1.1126708984375
#  > Real-time factor: 0.17911454058044385
#  > Text splitted to sentences.
# ['Speech synthesis is widely used in voice assistants and audiobooks.']
#  > Processing time: 0.576164722442627
#  > Real-time factor: 0.10786944818859466
#  > Text splitted to sentences.
# ['Multilingual models allow working with several languages at once.']
#  > Processing time: 0.5450501441955566
#  > Real-time factor: 0.10992934728077002
#  > Text splitted to sentences.
# ['The quality of synthesis can be evaluated both subjectively and using formal metrics.']
#  > Processing time: 0.7763829231262207
#  > Real-time factor: 0.12004406102696319

# %%
# Bark

from bark import generate_audio, SAMPLE_RATE
import soundfile as sf

glow_tts_model_name = "bark"
output_dir = Path("models") / glow_tts_model_name
output_dir.mkdir(parents=True, exist_ok=True)


def bark_to_file(text, file_path):
    audio_arr = generate_audio(text)
    sf.write(file_path, audio_arr, SAMPLE_RATE)


bark_report = evaluate_tts_model(
    glow_tts_model_name,
    bark_to_file,
    warmup_kwargs={
        "text": WARMUP_TEXT,
        "file_path": create_temp_wav(f"{glow_tts_model_name}_warmup"),
    },
    benchmark_kwargs={
        "text": BENCHMARK_TEXT,
        "file_path": create_temp_wav(f"{glow_tts_model_name}_bench"),
    },
)

stats[glow_tts_model_name]["report"] = dict(bark_report)

for i, sequence in enumerate(corpus):
    output_path = output_dir / f"{i}.wav"
    dt = timer(
        bark_to_file,
        text=sequence,
        file_path=str(output_path),
    )

    stats[glow_tts_model_name]["deltas"].append(dt)
    record_run(glow_tts_model_name, str(output_path), dt, bark_report)

stats[glow_tts_model_name]["report"].update(summarize_deltas(stats[glow_tts_model_name]["deltas"]))
# Out:
# WARNING:bark.generation:No GPU being used. Careful, inference might be very slow!
# text_2.pt:   0%|          | 0.00/5.35G [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 16
#      12     audio_arr = generate_audio(text)
#      13     sf.write(file_path, audio_arr, SAMPLE_RATE)
# ---> 16 bark_report = evaluate_tts_model(
#      17     model_name,
#      18     bark_to_file,
#      19     warmup_kwargs={
#      20         "text": WARMUP_TEXT,
#      21         "file_path": create_temp_wav(f"{model_name}_warmup"),
#      22     },
#      23     benchmark_kwargs={
#      24         "text": BENCHMARK_TEXT,
#      25         "file_path": create_temp_wav(f"{model_name}_bench"),
#      26     },
#      27 )
#      29 stats[model_name]["report"] = dict(bark_report)
#      31 for i, sequence in enumerate(corpus):
#
# Cell In[1], line 129, in evaluate_tts_model(name, synth_fn, warmup_kwargs, benchmark_kwargs, model_obj)
#     126     torch.cuda.reset_peak_memory_stats()
#     128 try:
# --> 129     _run(warmup_kwargs)
#     130 except Exception as exc:
#     131     print(f"[{name}] Warmup error: {exc}")
#
# Cell In[1], line 117, in evaluate_tts_model.<locals>._run(call_kwargs)
#     115 tmp_path = kwargs.get("file_path")
#     116 try:
# --> 117     synth_fn(**kwargs)
#     118 finally:
#     119     if tmp_path and os.path.exists(tmp_path):
#
# Cell In[4], line 12, in bark_to_file(text, file_path)
#      11 def bark_to_file(text, file_path):
# ---> 12     audio_arr = generate_audio(text)
#      13     sf.write(file_path, audio_arr, SAMPLE_RATE)
#
# File /opt/homebrew/lib/python3.11/site-packages/bark/api.py:107, in generate_audio(text, history_prompt, text_temp, waveform_temp, silent, output_full)
#      86 def generate_audio(
#      87     text: str,
#      88     history_prompt: Optional[Union[Dict, str]] = None,
#    (...)
#      92     output_full: bool = False,
#      93 ):
#      94     """Generate audio array from input text.
#      95
#      96     Args:
#    (...)
#     105         numpy audio array at sample frequency 24khz
#     106     """
# --> 107     semantic_tokens = text_to_semantic(
#     108         text,
#     109         history_prompt=history_prompt,
#     110         temp=text_temp,
#     111         silent=silent,
#     112     )
#     113     out = semantic_to_waveform(
#     114         semantic_tokens,
#     115         history_prompt=history_prompt,
#    (...)
#     118         output_full=output_full,
#     119     )
#     120     if output_full:
#
# File /opt/homebrew/lib/python3.11/site-packages/bark/api.py:25, in text_to_semantic(text, history_prompt, temp, silent)
#       8 def text_to_semantic(
#       9     text: str,
#      10     history_prompt: Optional[Union[Dict, str]] = None,
#      11     temp: float = 0.7,
#      12     silent: bool = False,
#      13 ):
#      14     """Generate semantic array from text.
#      15
#      16     Args:
#    (...)
#      23         numpy semantic array to be fed into `semantic_to_waveform`
#      24     """
# ---> 25     x_semantic = generate_text_semantic(
#      26         text,
#      27         history_prompt=history_prompt,
#      28         temp=temp,
#      29         silent=silent,
#      30         use_kv_caching=True
#      31     )
#      32     return x_semantic
#
# File /opt/homebrew/lib/python3.11/site-packages/bark/generation.py:409, in generate_text_semantic(text, history_prompt, temp, top_k, top_p, silent, min_eos_p, max_gen_duration_s, allow_early_stop, use_kv_caching)
#     407 global models_devices
#     408 if "text" not in models:
# --> 409     preload_models()
#     410 model_container = models["text"]
#     411 model = model_container["model"]
#
# File /opt/homebrew/lib/python3.11/site-packages/bark/generation.py:318, in preload_models(text_use_gpu, text_use_small, coarse_use_gpu, coarse_use_small, fine_use_gpu, fine_use_small, codec_use_gpu, force_reload)
#     314 if _grab_best_device() == "cpu" and (
#     315     text_use_gpu or coarse_use_gpu or fine_use_gpu or codec_use_gpu
#     316 ):
#     317     logger.warning("No GPU being used. Careful, inference might be very slow!")
# --> 318 _ = load_model(
#     319     model_type="text", use_gpu=text_use_gpu, use_small=text_use_small, force_reload=force_reload
#     320 )
#     321 _ = load_model(
#     322     model_type="coarse",
#     323     use_gpu=coarse_use_gpu,
#     324     use_small=coarse_use_small,
#     325     force_reload=force_reload,
#     326 )
#     327 _ = load_model(
#     328     model_type="fine", use_gpu=fine_use_gpu, use_small=fine_use_small, force_reload=force_reload
#     329 )
#
# File /opt/homebrew/lib/python3.11/site-packages/bark/generation.py:275, in load_model(use_gpu, use_small, force_reload, model_type)
#     273     ckpt_path = _get_ckpt_path(model_type, use_small=use_small)
#     274     clean_models(model_key=model_key)
# --> 275     model = _load_model_f(ckpt_path, device)
#     276     models[model_key] = model
#     277 if model_type == "text":
#
# File /opt/homebrew/lib/python3.11/site-packages/bark/generation.py:211, in _load_model(ckpt_path, device, use_small, model_type)
#     209 if not os.path.exists(ckpt_path):
#     210     logger.info(f"{model_type} model not found, downloading into `{CACHE_DIR}`.")
# --> 211     _download(model_info["repo_id"], model_info["file_name"])
#     212 checkpoint = torch.load(ckpt_path, map_location=device)
#     213 # this is a hack
#
# File /opt/homebrew/lib/python3.11/site-packages/bark/generation.py:151, in _download(from_hf_path, file_name)
#     149 def _download(from_hf_path, file_name):
#     150     os.makedirs(CACHE_DIR, exist_ok=True)
# --> 151     hf_hub_download(repo_id=from_hf_path, filename=file_name, local_dir=CACHE_DIR)
#
# File /opt/homebrew/lib/python3.11/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/huggingface_hub/file_download.py:842, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, proxies, etag_timeout, token, local_files_only, headers, endpoint, resume_download, force_filename, local_dir_use_symlinks)
#     833     if local_dir_use_symlinks != "auto":
#     834         warnings.warn(
#     835             "`local_dir_use_symlinks` parameter is deprecated and will be ignored. "
#     836             "The process to download files to a local folder has been updated and do "
#    (...)
#     839             "For more details, check out https://huggingface.co/docs/huggingface_hub/main/en/guides/download#download-files-to-local-folder."
#     840         )
# --> 842     return _hf_hub_download_to_local_dir(
#     843         # Destination
#     844         local_dir=local_dir,
#     845         # File info
#     846         repo_id=repo_id,
#     847         repo_type=repo_type,
#     848         filename=filename,
#     849         revision=revision,
#     850         # HTTP info
#     851         endpoint=endpoint,
#     852         etag_timeout=etag_timeout,
#     853         headers=hf_headers,
#     854         proxies=proxies,
#     855         token=token,
#     856         # Additional options
#     857         cache_dir=cache_dir,
#     858         force_download=force_download,
#     859         local_files_only=local_files_only,
#     860     )
#     861 else:
#     862     return _hf_hub_download_to_cache_dir(
#     863         # Destination
#     864         cache_dir=cache_dir,
#    (...)
#     878         force_download=force_download,
#     879     )
#
# File /opt/homebrew/lib/python3.11/site-packages/huggingface_hub/file_download.py:1138, in _hf_hub_download_to_local_dir(local_dir, repo_id, repo_type, filename, revision, endpoint, etag_timeout, headers, proxies, token, cache_dir, force_download, local_files_only)
#    1136 with WeakFileLock(paths.lock_path):
#    1137     paths.file_path.unlink(missing_ok=True)  # delete outdated file first
# -> 1138     _download_to_tmp_and_move(
#    1139         incomplete_path=paths.incomplete_path(etag),
#    1140         destination_path=paths.file_path,
#    1141         url_to_download=url_to_download,
#    1142         proxies=proxies,
#    1143         headers=headers,
#    1144         expected_size=expected_size,
#    1145         filename=filename,
#    1146         force_download=force_download,
#    1147     )
#    1149 write_download_metadata(local_dir=local_dir, filename=filename, commit_hash=commit_hash, etag=etag)
#    1150 return str(paths.file_path)
#
# File /opt/homebrew/lib/python3.11/site-packages/huggingface_hub/file_download.py:1547, in _download_to_tmp_and_move(incomplete_path, destination_path, url_to_download, proxies, headers, expected_size, filename, force_download)
#    1544         _check_disk_space(expected_size, incomplete_path.parent)
#    1545         _check_disk_space(expected_size, destination_path.parent)
# -> 1547     http_get(
#    1548         url_to_download,
#    1549         f,
#    1550         proxies=proxies,
#    1551         resume_size=resume_size,
#    1552         headers=headers,
#    1553         expected_size=expected_size,
#    1554     )
#    1556 logger.info(f"Download complete. Moving file to {destination_path}")
#    1557 _chmod_and_move(incomplete_path, destination_path)
#
# File /opt/homebrew/lib/python3.11/site-packages/huggingface_hub/file_download.py:454, in http_get(url, temp_file, proxies, resume_size, headers, expected_size, displayed_filename, _nb_retries, _tqdm_bar)
#     452 new_resume_size = resume_size
#     453 try:
# --> 454     for chunk in r.iter_content(chunk_size=constants.DOWNLOAD_CHUNK_SIZE):
#     455         if chunk:  # filter out keep-alive new chunks
#     456             progress.update(len(chunk))
#
# File /opt/homebrew/lib/python3.11/site-packages/requests/models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File /opt/homebrew/lib/python3.11/site-packages/urllib3/response.py:628, in HTTPResponse.stream(self, amt, decode_content)
#     626 else:
#     627     while not is_fp_closed(self._fp):
# --> 628         data = self.read(amt=amt, decode_content=decode_content)
#     630         if data:
#     631             yield data
#
# File /opt/homebrew/lib/python3.11/site-packages/urllib3/response.py:567, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     564 fp_closed = getattr(self._fp, "closed", False)
#     566 with self._error_catcher():
# --> 567     data = self._fp_read(amt) if not fp_closed else b""
#     568     if amt is None:
#     569         flush_decoder = True
#
# File /opt/homebrew/lib/python3.11/site-packages/urllib3/response.py:533, in HTTPResponse._fp_read(self, amt)
#     530     return buffer.getvalue()
#     531 else:
#     532     # StringIO doesn't like amt=None
# --> 533     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File /opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:466, in HTTPResponse.read(self, amt)
#     463 if self.length is not None and amt > self.length:
#     464     # clip the read to the "end of response"
#     465     amt = self.length
# --> 466 s = self.fp.read(amt)
#     467 if not s and amt:
#     468     # Ideally, we would raise IncompleteRead if the content-length
#     469     # wasn't satisfied, but it might break compatibility.
#     470     self._close_conn()
#
# File /opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File /opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1311, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1307     if flags != 0:
#    1308         raise ValueError(
#    1309           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1310           self.__class__)
# -> 1311     return self.read(nbytes, buffer)
#    1312 else:
#    1313     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1167, in SSLSocket.read(self, len, buffer)
#    1165 try:
#    1166     if buffer is not None:
# -> 1167         return self._sslobj.read(len, buffer)
#    1168     else:
#    1169         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# xtts
xtts = TTS("tts_models/multilingual/multi-dataset/xtts_v2")
xtts = xtts.to(device)

glow_tts_model_name = "xtts"
output_dir = Path("models") / glow_tts_model_name
output_dir.mkdir(parents=True, exist_ok=True)

xtts_report = evaluate_tts_model(
    glow_tts_model_name,
    xtts.tts_to_file,
    warmup_kwargs={
        "text": WARMUP_TEXT,
        "language": "en",
        "file_path": create_temp_wav(f"{glow_tts_model_name}_warmup"),
    },
    benchmark_kwargs={
        "text": BENCHMARK_TEXT,
        "language": "en",
        "file_path": create_temp_wav(f"{glow_tts_model_name}_bench"),
    },
    model_obj=xtts,
)

stats[glow_tts_model_name]["report"] = dict(xtts_report)

for i, sequence in enumerate(corpus):
    output_path = output_dir / f"{i}.wav"
    dt = timer(
        xtts.tts_to_file,
        text=sequence,
        file_path=str(output_path),
        language="en",
    )

    stats[glow_tts_model_name]["deltas"].append(dt)
    record_run(glow_tts_model_name, str(output_path), dt, xtts_report)

stats[glow_tts_model_name]["report"].update(summarize_deltas(stats[glow_tts_model_name]["deltas"]))

# %%
# Whisper Speech

from whisperspeech.pipeline import Pipeline
import soundfile as sf

pipe = Pipeline()

glow_tts_model_name = "whisper-speech"
output_dir = Path("models") / glow_tts_model_name
output_dir.mkdir(parents=True, exist_ok=True)


def whisper_to_file(text, file_path):
    audio = pipe.generate_audio(text)
    sf.write(file_path, audio, 16000)


whisper_report = evaluate_tts_model(
    glow_tts_model_name,
    whisper_to_file,
    warmup_kwargs={
        "text": WARMUP_TEXT,
        "file_path": create_temp_wav(f"{glow_tts_model_name}_warmup"),
    },
    benchmark_kwargs={
        "text": BENCHMARK_TEXT,
        "file_path": create_temp_wav(f"{glow_tts_model_name}_bench"),
    },
)

stats[glow_tts_model_name]["report"] = dict(whisper_report)

for i, sequence in enumerate(corpus):
    output_path = output_dir / f"{i}.wav"

    dt = timer(
        whisper_to_file,
        text=sequence,
        file_path=str(output_path),
    )

    stats[glow_tts_model_name]["deltas"].append(dt)
    record_run(glow_tts_model_name, str(output_path), dt, whisper_report)

stats[glow_tts_model_name]["report"].update(summarize_deltas(stats[glow_tts_model_name]["deltas"]))

# %%
# Persist metrics report
save_report(report_rows, report_csv_path)
stats
# Out:
# Saved report to reports/lab4_report.csv (10 rows).
# {'bark': {'report': {}, 'deltas': []},
#  'fastspeech': {'report': {}, 'deltas': []},
#  'vits': {'report': {'model_name': 'vits',
#    'benchmark_synthesis_time_s': 0.7924511432647705,
#    'model_size_mb': 138.55462646484375,
#    'cpu_load_percent': 97.1,
#    'ram_usage_mb': 1348.84375,
#    'gpu_usage_mb': None,
#    'num_runs': 10,
#    'mean_runtime_s': 0.7027400493621826,
#    'median_runtime_s': 0.6386858224868774,
#    'std_runtime_s': 0.17438568981140987,
#    'min_runtime_s': 0.5424678325653076,
#    'max_runtime_s': 1.123274326324463},
#   'deltas': [0.556908130645752,
#    0.7674808502197266,
#    0.8372459411621094,
#    0.5424678325653076,
#    0.5814900398254395,
#    0.6918158531188965,
#    1.123274326324463,
#    0.5855557918548584,
#    0.5535428524017334,
#    0.78761887550354]},
#  'xtts': {'report': {}, 'deltas': []},
#  'whisper-speech': {'report': {}, 'deltas': []}}
